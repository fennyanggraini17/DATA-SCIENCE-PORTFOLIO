# %% [markdown]
# <a id="9"></a>
#
#
# <font color="GRAY" size=+3><b> ASSIGNMENT 3 </b></font>
#
# <a id="4"></a>
#
# ---
# <font color="GREEN" size=+1><b> FENNY ANGGRAINI -  DS04038 </b></font>
#
# ---

# %% [markdown]
# <a id="5"></a>
#
#
# <font color="DimGray" size=+2.5><b>Analisis Data Heart Disease Dataset</b></font>

# %% [markdown]
# Dataset yang digunakan ini berasal dari tahun 1988 dan terdiri dari empat database: Cleveland, Hungaria, Swiss, dan Long Beach V. Ini berisi 76 atribut, termasuk atribut yang diprediksi, tetapi semua percobaan yang dipublikasikan mengacu pada penggunaan subset dari 14 atribut tersebut. Bidang "target" mengacu pada adanya penyakit jantung pada pasien. Itu adalah bilangan bulat bernilai 0 = tidak ada penyakit dan 1 = penyakit.
#
# Dataset yang saya gunakan berbentuk kumpulan data berupa file csv yang kami ambil dari kaggle.com, yang tersedia pada link berikut https://www.kaggle.com/datasets/johnsmith88/heart-disease-dataset.

# %% [markdown]
# <a id="4"></a>
#
# ---
# <font color="BROWN" size=+2><b> INTRUKSI </b></font>
#
# ---
#
# **Instruksi Assignment 2**
#
# Pilih salah satu studi kasus yang tersedia:
# 1. Tentukan masalah bisnis, metrik, sasaran
# 2. Tentukan alur kerja yang akan Anda gunakan jika Anda seorang ilmuwan data yang bekerja dalam kasus ini
# 3. Periksa kualitas kumpulan data (nilai yang hilang , duplikat, outlier, ketidakseimbangan data)
# 4. Periksa statistik deskriptif dari kumpulan data (rata-rata, distribusi, dll)
# 5. Periksa korelasi antar fitur
# 6. Visualisasikan poin 4 dan 5
# 7. Jelaskan kemungkinan teknik feature engineering melalui encoding
# 8. Otomasi EDA melalui Dataprep, Autovis, Dtale, dll.
#
# **Intruksi Assignment 3**
#
# Anda telah melakukan beberapa pekerjaan untuk pra-pemrosesan data untuk tugas terakhir. Dengan menggunakan kumpulan data yang dipilih (dalam tugas 2), Anda harus:
# 1. Buat hipotesis dari model yang akan Anda buat.
# 2. Pilih setidaknya 2 model dari sesi langsung (atau yang lain yang Anda ketahui) dan beri alasan mengapa menurut Anda akan bermanfaat bagi Anda untuk memilih model untuk kumpulan data.
# 3. Lakukan validasi silang dan bootstrap
# 4. Buat minimal 2 model
# 5. Sebutkan evaluasi model yang akan Anda gunakan untuk diterapkan dalam proyek dan justifikasinya, dan evaluasi model yang telah Anda buat.
# 6. Buat daftar kepentingan fitur dari model yang telah Anda buat dan dapatkan wawasan yang berkaitan dengan kepentingan fitur.

# %% [markdown]
# <a id="4"></a>
#
# ---
# <font color="BROWN" size=+2><b> MASALAH BISNIS, METRIK, DAN SASARAN </b></font>
#
# ---
#
# <font color="Black" size=+0.5><b> Masalah Bisnis :</b></font>
# - Memperkirakan risiko penyakit jantung pada pasien berdasarkan data klinis yang tersedia.
# - Memprediksi apakah seorang pasien memiliki penyakit jantung berdasarkan 14 atribut yang diberikan. Dalam dunia medis, ini sangat penting karena dapat membantu dokter dan tenaga medis dalam memutuskan tindakan pengobatan yang harus diambil.
#
#
# <font color="Black" size=+0.5><b> Metrik :</b></font>
# - Akurasi (accuracy) yang merupakan rasio antara jumlah prediksi yang benar dengan jumlah total prediksi. Namun, karena dataset ini memiliki kelas yang tidak seimbang, di mana jumlah pasien dengan penyakit jantung lebih sedikit dari yang sehat, maka selain akurasi, juga dapat digunakan metrik seperti presisi, recall, F1-score, dan Area Under ROC Curve (AUC-ROC).
#
# <font color="Black" size=+0.5><b> Sasaran :</b></font>
# - Memprediksi dengan akurasi sebaik mungkin apakah seorang pasien berisiko terkena penyakit jantung atau tidak, sehingga dapat membantu dokter dalam memberikan pengobatan dan tindakan pencegahan yang tepat dan waktu. Sasaran yang spesifik dapat ditentukan berdasarkan kebutuhan bisnis, seperti mengurangi jumlah pasien yang salah terdiagnosis, atau meningkatkan jumlah pasien yang terdeteksi dengan risiko penyakit jantung yang tinggi.
# - untuk mengembangkan model dengan tingkat akurasi yang diharapkan dapat mencapai di atas 80%. Selain itu, juga diharapkan model dapat memiliki nilai presisi dan recall yang seimbang agar dapat memberikan hasil yang akurat dan berguna bagi dokter dan tenaga medis.

# %% [markdown]
# <a id="4"></a>
#
# ---
# <font color="BROWN" size=+2><b> Menentukan alur kerja yang akan digunakan </b></font>
#
# ---
#
# Sebagai seorang ilmuwan data, berikut adalah alur kerja yang dapat diikuti untuk menangani dataset penyakit jantung:
#
# 1. Pertama-tama, kita perlu memahami dan mengklasifikasikan setiap atribut yang tersedia dalam dataset. Ini akan membantu dalam memahami bagaimana masing-masing atribut mempengaruhi kemungkinan penyakit jantung.
# 2. Selanjutnya, kita perlu melakukan eksplorasi data dengan memvisualisasikan data menggunakan grafik seperti histogram, scatter plot, dan box plot. Ini akan membantu kita memahami distribusi data, melihat korelasi antara atribut, serta mengidentifikasi dan mengatasi nilai yang hilang dan outliers.
# 3. Setelah itu, kita perlu melakukan pre-processing data seperti normalisasi data dan mengatasi nilai yang hilang.
# 4. Kemudian, kita dapat membagi data menjadi dua bagian yaitu data training dan data testing. Data training digunakan untuk melatih model dan data testing digunakan untuk menguji model.
# 5. Selanjutnya, kita perlu memilih model yang paling cocok untuk kasus ini. Beberapa model yang bisa digunakan adalah Decision Tree, Random Forest, Naive Bayes, dan Logistic Regression.
# 6. Setelah memilih model yang cocok, kita dapat melatih model menggunakan data training dan menguji model menggunakan data testing. Kemudian, kita dapat mengevaluasi model menggunakan metrik seperti akurasi, presisi, recall, dan F1-score.
# 7. Jika model masih belum memenuhi persyaratan, kita dapat memilih untuk memperbaiki model dengan menggunakan teknik seperti cross-validation, hyperparameter tuning, dan ensemble learning.
# 8. Setelah model yang cocok dan akurat ditemukan, kita dapat menggunakannya untuk memprediksi kemungkinan adanya penyakit jantung pada pasien baru berdasarkan nilai atribut yang dimasukkan.

# %% [markdown]
# <a id="5"></a>
#
#
# <font color="black" size=+2><b> Import Library</b></font>

# %%
# !pip install dataprep
# !pip install autoviz
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy.stats import pearsonr
from dataprep.eda import create_report
from autoviz.AutoViz_Class import AutoViz_Class

# %matplotlib inline

# %% [markdown]
# ##**Importing Dataset**

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-4474816f-9bb6-4dec-a585-0487de8653e4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4474816f-9bb6-4dec-a585-0487de8653e4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io
df = pd.read_csv(io.BytesIO(uploaded['heart.csv']))

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
df.tail()
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0

# %% [markdown]
# ##**Describing Dataset**

# %% [markdown]
# <a id="5"></a>
#
#
# <font color="PURPLE" size=+1.5><b> Melihat jumlah dataset (jumlah baris dan kolom)</b></font>

# %%
df.shape
# Out:
# (1025, 14)

# %% [markdown]
# Pada dataset terlihat terdapat 1025 baris dengan 14 kolom.

# %% [markdown]
# <a id="5"></a>
#
#
# <font color="PURPLE" size=+1.5><b> Melihat columns apa saja yang ada dalam  dataset</b></font>

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %% [markdown]
# 1. Age: variabel ini merepresentasikan usia pasien yang diukur dalam tahun.
# 2. Sex: variabel ini merepresentasikan jenis kelamin pasien dengan nilai 1 untuk laki-laki dan nilai 0 untuk perempuan.
# 3. cp (Chest pain type): variabel ini merepresentasikan jenis nyeri dada yang dirasakan oleh pasien dengan 4 nilai kategori yang mungkin: nilai 1 mengindikasikan nyeri dada tipe angina, nilai 2 mengindikasikan nyeri dada tipe nyeri tidak stabil, nilai 3 mengindikasikan nyeri dada tipe nyeri tidak stabil yang parah, dan nilai 4 mengindikasikan nyeri dada yang tidak terkait dengan masalah jantung.
# 4. trestbps (Resting blood pressure): variabel ini merepresentasikan tekanan darah pasien pada saat istirahat, diukur dalam mmHg (milimeter air raksa (merkuri)).
# 5. chol (Serum cholestoral): variabel ini merepresentasikan kadar kolesterol serum dalam darah pasien, diukur dalam mg/dl (miligram per desiliter).
# 6. fbs (Fasting blood sugar): variabel ini merepresentasikan kadar gula darah pasien saat puasa (belum makan) dengan nilai 1 jika kadar gula darah > 120 mg/dl dan nilai 0 jika tidak.
# 7. restecg (Resting electrocardiographic results): variabel ini merepresentasikan hasil elektrokardiogram pasien saat istirahat dengan 3 nilai kategori yang mungkin: nilai 0 mengindikasikan hasil normal, nilai 1 mengindikasikan adanya kelainan gelombang ST-T, dan nilai 2 mengindikasikan hipertrofi ventrikel kiri.
# 8. thalach (Maximum heart rate achieved): variabel ini merepresentasikan detak jantung maksimum yang dicapai oleh pasien selama tes olahraga, diukur dalam bpm (denyut per menit).
# 9. exang (Exercise induced angina): variabel ini merepresentasikan apakah pasien mengalami angina (nyeri dada) yang dipicu oleh aktivitas olahraga, dengan nilai 1 jika ya dan nilai 0 jika tidak.
# 10. Oldpeak: variabel ini merepresentasikan seberapa banyak ST segmen menurun atau depresi saat melakukan aktivitas fisik dibandingkan saat istirahat.
# 11. Slope: variabel ini merepresentasikan kemiringan segmen ST pada elektrokardiogram (EKG) selama latihan fisik maksimal dengan 3 nilai kategori.
# 12. ca (Number of major vessels): variabel ini merepresentasikan jumlah pembuluh darah utama (0-3) yang terlihat pada pemeriksaan flourosopi.
# 13. Thal: variabel ini merepresentasikan hasil tes thalium scan dengan 3 nilai kategori yang mungkin:
#   *   thal 1: menunjukkan kondisi normal.
#   *   thal 2: menunjukkan adanya defek tetap pada thalassemia.
#   *   thal 3: menunjukkan adanya defek yang dapat dipulihkan pada thalassemia.
# 14. Target: 0 = tidak ada penyakit dan 1 = penyakit.

# %% [markdown]
# <a id="5"></a>
#
#
# <font color="PURPLE" size=+1.5><b> Melihat persebaran data</b></font>

# %%
df.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# ...

# %% [markdown]
# ##**Periksa kualitas data (missing value, outlier, duplikat, data imbalance)**

# %% [markdown]
# <a id="5"></a>
#
#
# <font color="PURPLE" size=+1.5><b> Melihat informasi dasar dari dataset</b></font>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %% [markdown]
# Terdapat beberapa tipe data pada kolom yang tidak sesuai.

# %% [markdown]
# <a id="5"></a>
#
#
# <font color="PURPLE" size=+1.5><b> Mengubah beberapa kolom menjadi kategorikal</b></font>

# %%
# Ubah daftar kolom berikut menjadi kategorikal
lst=['sex', 'cp', 'fbs', 'restecg', 'exang', 'slope', 'ca', 'thal']
df[lst] = df[lst].astype(object)

# %%
df.dtypes
# Out:
# age           int64
# sex          object
# cp           object
# trestbps      int64
# chol          int64
# fbs          object
# restecg      object
# thalach       int64
# exang        object
# oldpeak     float64
# slope        object
# ca           object
# thal         object
# target        int64
# dtype: object

# %%
# Pisahkan numerical dan categorical
numerical_col = df.select_dtypes(exclude=np.object_)
categorical_col = df.select_dtypes(exclude=np.number)

# %% [markdown]
# <a id="5"></a>
#
#
# <font color="PURPLE" size=+1.5><b> Missing Values</b></font>

# %%
mv = df.isnull().sum()
mv
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %% [markdown]
# Berdasarkan output diatas, dapat dilihat tidak adanya missing value pada dataset

# %% [markdown]
# <a id="5"></a>
#
#
# <font color="PURPLE" size=+1.5><b> Data Duplikat</b></font>

# %%
# Memeriksa duplikat data
df.duplicated().sum()
# Out:
# 723

# %% [markdown]
# Berdasarkan output diatas, terdapat 723 baris yang memiliki duplikat data pada dataset tersebut. Oleh karena itu, harus dilakukan drop duplikat data agar tidak ada data yang duplikat dalam dataset.

# %%
df.drop_duplicates(inplace=True)

# %%
# Memeriksa ulang duplikat data
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Setelah dilakukan drop data yang duplikat maka terlihat tidak adanya lagi data yang duplikat pada dataset.

# %% [markdown]
# <a id="5"></a>
#
#
# <font color="PURPLE" size=+1.5><b> Memeriksa Skewness</b></font>

# %%
df.skew()
# Out:
# age        -0.203743
# sex        -0.786120
# cp          0.493022
# trestbps    0.716541
# chol        1.147332
# fbs         1.981201
# restecg     0.169467
# thalach    -0.532671
# exang       0.737281
# oldpeak     1.266173
# slope      -0.503247
# ca          1.295738
# thal       -0.481232
# target     -0.173691
# dtype: float64

# %% [markdown]
# Berdasarkan output diatas, beberapa kolom skewed positif dan beberapa skewed negatif.

# %%
## check distributions
plt.figure(figsize=(15,20), facecolor='white')
plotnumber = 1

for column in df.columns:
    if plotnumber<15 :
        plt.subplot(4,4,plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()

# %% [markdown]
# <a id="5"></a>
#
# <font color="black" size=+1.5><b> Jumlah kategori sex pada dataset</font>

# %%
s = df['sex'].value_counts().reset_index()
s = s.rename(columns = {'sex' : 'total_pasien'}).sort_values(by = 'total_pasien', ascending = False)
s = s.rename(columns = {'index' : 'sex'}).sort_values(by = 'sex', ascending = False)
s
# Out:
#    sex  total_pasien
# 0    1           206
# 1    0            96

# %% [markdown]
# <a id="5"></a>
#
# <font color="black" size=+1.5><b> Jumlah kategori age pada dataset</b></font>

# %%
ag = df['age'].value_counts().reset_index()
ag = ag.rename(columns = {'age' : 'total_pasien'}).sort_values(by = 'total_pasien', ascending = True)
ag = ag.rename(columns = {'index' : 'age'}).sort_values(by = 'age', ascending = True)
ag
# Out:
#     age  total_pasien
# 38   29             1
# 36   34             2
# 29   35             4
# 34   37             2
# 35   38             2
# 30   39             4
# 32   40             3
# 10   41            10
# 14   42             8
# 15   43             8
# 6    44            11
# 19   45             8
# 22   46             7
# 26   47             5
# 24   48             7
# 25   49             5
# 21   50             7
# 5    51            12
# 4    52            13
# 17   53             8
# 2    54            16
# 20   55             8
# 8    56            11
# 1    57            17
# 0    58            19
# 3    59            14
# 7    60            11
# 18   61             8
# 9    62            11
# 13   63             9
# 11   64            10
# 16   65             8
# 23   66             7
# 12   67             9
# 27   68             4
# 31   69             3
# 28   70             4
# 33   71             3
# 40   74             1
# 37   76             1
# ...

# %% [markdown]
# <a id="5"></a>
#
# <font color="black" size=+1.5><b> Jumlah kategori jenis nyeri dada</b></font>

# %%
cp = df['cp'].value_counts().reset_index()
cp = cp.rename(columns = {'cp' : 'total_pasien'}).sort_values(by = 'total_pasien', ascending = False)
cp = cp.rename(columns = {'index' : 'chest_pain_type'}).sort_values(by = 'chest_pain_type', ascending = False)
cp
# Out:
#    chest_pain_type  total_pasien
# 3                3            23
# 1                2            86
# 2                1            50
# 0                0           143

# %% [markdown]
# <a id="5"></a>
#
# <font color="black" size=+1.5><b> Jumlah kategori tekanan darah saat istirahat</b></font>

# %%
tbps = df['trestbps'].value_counts().reset_index()
tbps = tbps.rename(columns = {'trestbps' : 'total_pasien'}).sort_values(by = 'total_pasien', ascending = False)
tbps = tbps.rename(columns = {'index' : 'Resting_blood_pressure'}).sort_values(by = 'Resting_blood_pressure', ascending = False)
tbps
# Out:
#     Resting_blood_pressure  total_pasien
# 40                     200             1
# 44                     192             1
# 23                     180             3
# 31                     178             2
# 33                     174             1
# 37                     172             1
# 20                     170             4
# 34                     165             1
# 36                     164             1
# 8                      160            11
# 35                     156             1
# 38                     155             1
# 41                     154             1
# 15                     152             5
# 4                      150            17
# 32                     148             2
# 30                     146             2
# 17                     145             5
# 27                     144             2
# 25                     142             3
# 2                      140            32
# 5                      138            12
# ...

# %% [markdown]
# <a id="5"></a>
#
# <font color="black" size=+1.5><b> Jumlah kategori kadar kolestrol serum dalam darah </b></font>

# %%
cl = df['chol'].value_counts().reset_index()
cl = cl.rename(columns = {'chol' : 'total_pasien'}).sort_values(by = 'total_pasien', ascending = False)
cl = cl.rename(columns = {'index' : 'Serum_cholestoral'}).sort_values(by = 'Serum_cholestoral', ascending = False)
cl
# Out:
#      Serum_cholestoral  total_pasien
# 142                564             1
# 148                417             1
# 137                409             1
# 108                407             1
# 101                394             1
# ..                 ...           ...
# 141                157             1
# 71                 149             2
# 151                141             1
# 122                131             1
# 150                126             1
#
# [152 rows x 2 columns]

# %% [markdown]
# <a id="5"></a>
#
# <font color="black" size=+1.5><b> Jumlah kategori gula darah saat puasa </b></font>

# %%
fbs = df['fbs'].value_counts().reset_index()
fbs = fbs.rename(columns = {'fbs' : 'total_pasien'}).sort_values(by = 'total_pasien', ascending = False)
fbs = fbs.rename(columns = {'index' : 'fasting_blood_sugar'}).sort_values(by = 'fasting_blood_sugar', ascending = False)
fbs
# Out:
#    fasting_blood_sugar  total_pasien
# 1                    1            45
# 0                    0           257

# %% [markdown]
# <a id="5"></a>
#
# <font color="black" size=+1.5><b> Jumlah kategori hasil electrocardiographic</b></font>

# %%
rcg = df['restecg'].value_counts().reset_index()
rcg = rcg.rename(columns = {'restecg' : 'total_pasien'}).sort_values(by = 'total_pasien', ascending = False)
rcg = rcg.rename(columns = {'index' : 'Resting_electrocardiographic_results'}).sort_values(by = 'Resting_electrocardiographic_results', ascending = False)
rcg
# Out:
#    Resting_electrocardiographic_results  total_pasien
# 2                                     2             4
# 0                                     1           151
# 1                                     0           147

# %% [markdown]
# <a id="5"></a>
#
# <font color="black" size=+1.5><b> Jumlah kategori detak jantung maximum selama tes olahraga</b></font>

# %%
thl = df['thalach'].value_counts().reset_index()
thl = thl.rename(columns = {'thalach' : 'total_pasien'}).sort_values(by = 'total_pasien', ascending = False)
thl = thl.rename(columns = {'index' : 'Maximum_heart_rate_achieved'}).sort_values(by = 'Maximum_heart_rate_achieved', ascending = False)
thl
# Out:
#     Maximum_heart_rate_achieved  total_pasien
# 85                          202             1
# 82                          195             1
# 78                          194             1
# 76                          192             1
# 80                          190             1
# ..                          ...           ...
# 51                           96             2
# 89                           95             1
# 73                           90             1
# 83                           88             1
# 66                           71             1
#
# [91 rows x 2 columns]

# %% [markdown]
# <a id="5"></a>
#
# <font color="black" size=+1.5><b> Jumlah kategori pasien yang mengalami nyeri dada selama tes olahraga</b></font>

# %%
ex = df['exang'].value_counts().reset_index()
ex = ex.rename(columns = {'exang' : 'total_pasien'}).sort_values(by = 'total_pasien', ascending = False)
ex = ex.rename(columns = {'index' : 'Exercise_induced_angina'}).sort_values(by = 'Exercise_induced_angina', ascending = False)
ex
# Out:
#    Exercise_induced_angina  total_pasien
# 1                        1            99
# 0                        0           203

# %% [markdown]
# <a id="5"></a>
#
# <font color="black" size=+1.5><b> Jumlah kategori pasien yang mengalami depresi saat melakukan aktivitas fisik dibandingkan saat istirahat</b></font>

# %%
op = df['oldpeak'].value_counts().reset_index()
op = op.rename(columns = {'oldpeak' : 'total_pasien'}).sort_values(by = 'total_pasien', ascending = False)
op = op.rename(columns = {'index' : 'oldpeak'}).sort_values(by = 'oldpeak', ascending = False)
op
# Out:
#     oldpeak  total_pasien
# 33      6.2             1
# 36      5.6             1
# 37      4.4             1
# 28      4.2             2
# 24      4.0             3
# 31      3.8             1
# 18      3.6             4
# 39      3.5             1
# 20      3.4             3
# 25      3.2             2
# 35      3.1             1
# 15      3.0             5
# 38      2.9             1
# 12      2.8             6
# 13      2.6             6
# 29      2.5             2
# 23      2.4             3
# 26      2.3             2
# 19      2.2             4
# 32      2.1             1
# 9       2.0             9
# 14      1.9             5
# 8       1.8            10
# 7       1.6            11
# 17      1.5             5
# 5       1.4            13
# 30      1.3             1
# 1       1.2            17
# 27      1.1             2
# 3       1.0            14
# 22      0.9             3
# 4       0.8            13
# 34      0.7             1
# 2       0.6            14
# ...

# %% [markdown]
# <a id="5"></a>
#
# <font color="black" size=+1.5><b> Jumlah kategori kemiringan segmen ST pada elektrokardiogram (EKG) selama latihan fisik </b></font>

# %%
sp = df['slope'].value_counts().reset_index()
sp = sp.rename(columns = {'slope' : 'total_pasien'}).sort_values(by = 'total_pasien', ascending = False)
sp = sp.rename(columns = {'index' : 'slope'}).sort_values(by = 'slope', ascending = False)
sp
# Out:
#    slope  total_pasien
# 0      2           141
# 1      1           140
# 2      0            21

# %% [markdown]
# <a id="5"></a>
#
# <font color="black" size=+1.5><b> Jumlah kategori pembuluh darah utama pada pemeriksaan flourosopi. </b></font>

# %%
ca = df['ca'].value_counts().reset_index()
ca = ca.rename(columns = {'ca' : 'total_pasien'}).sort_values(by = 'total_pasien', ascending = False)
ca = ca.rename(columns = {'index' : 'Number_of_major_vessels'}).sort_values(by = 'Number_of_major_vessels', ascending = False)
ca
# Out:
#    Number_of_major_vessels  total_pasien
# 4                        4             4
# 3                        3            20
# 2                        2            38
# 1                        1            65
# 0                        0           175

# %% [markdown]
# <a id="5"></a>
#
# <font color="black" size=+1.5><b> Jumlah kategori hasil tes thalium scan</b></font>

# %%
ts = df['thal'].value_counts().reset_index()
ts = ts.rename(columns = {'thal' : 'total_pasien'}).sort_values(by = 'total_pasien', ascending = False)
ts = ts.rename(columns = {'index' : 'thalium_scan_result'}).sort_values(by = 'thalium_scan_result', ascending = False)
ts
# Out:
#    thalium_scan_result  total_pasien
# 1                    3           117
# 0                    2           165
# 2                    1            18
# 3                    0             2

# %% [markdown]
# <a id="5"></a>
#
# <font color="black" size=+1.5><b> Jumlah kategori pasien memiliki dan tidak memiliki penyakit</b></font>

# %%
Tgt = df['target'].value_counts().reset_index()
Tgt = Tgt.rename(columns = {'target' : 'total_pasien'}).sort_values(by = 'total_pasien', ascending = False)
Tgt = Tgt.rename(columns = {'index' : 'target'}).sort_values(by = 'target', ascending = False)
Tgt
# Out:
#    target  total_pasien
# 0       1           164
# 1       0           138

# %% [markdown]
# <a id="5"></a>
#
#
# <font color="PURPLE" size=+1.5><b> Memeriksa Outlier</b></font>

# %%
## Menggunakan describe()
df.describe()
# Out:
#              age    trestbps        chol     thalach     oldpeak      target
# count  302.00000  302.000000  302.000000  302.000000  302.000000  302.000000
# mean    54.42053  131.602649  246.500000  149.569536    1.043046    0.543046
# std      9.04797   17.563394   51.753489   22.903527    1.161452    0.498970
# min     29.00000   94.000000  126.000000   71.000000    0.000000    0.000000
# 25%     48.00000  120.000000  211.000000  133.250000    0.000000    0.000000
# 50%     55.50000  130.000000  240.500000  152.500000    0.800000    1.000000
# 75%     61.00000  140.000000  274.750000  166.000000    1.600000    1.000000
# max     77.00000  200.000000  564.000000  202.000000    6.200000    1.000000

# %% [markdown]
# Berdasarkan output di atas kita dapat melihat ada perbedaan besar dalam chol 75% hingga max (274.75 hingga 564.0) demikian pula kita dapat melihat di thalch, trestbps, oldpeak sehingga mengindikasikan adanya outlier.

# %%
plt.figure(figsize=(20,20), facecolor='white')

plotnumber=1
for column in df.columns:
    if plotnumber<15 :
        plt.subplot(4,4,plotnumber)
        plt.boxplot(df[column])
        plt.ylabel(column,fontsize=20)
    plotnumber+=1
plt.show()

# %% [markdown]
# Berdasarkan output di atas ada beberapa atribut yang memiliki outlier seperti:
# - trestbps
# - chol
# - thalach
# - oldpeak
# - thal

# %% [markdown]
# <a id="5"></a>
#
#
# <font color="PURPLE" size=+1.5><b> Menghapus Data Outlier</b></font>

# %%
data_cleaned=pd.DataFrame()

# %% [markdown]
# **Menghapus outlier di trestbps**

# %%
df['trestbps'].unique()
# Out:
# array([125, 140, 145, 148, 138, 100, 114, 160, 120, 122, 112, 132, 118,
#        128, 124, 106, 104, 135, 130, 136, 180, 129, 150, 178, 146, 117,
#        152, 154, 170, 134, 174, 144, 108, 123, 110, 142, 126, 192, 115,
#         94, 200, 165, 102, 105, 155, 172, 164, 156, 101])

# %% [markdown]
# Dapat terlihat pada output diatas ada bebera outlier yang mana pada angka diatas 170-an di dalam dataset, diantaranya adalah (172, 174, 178, 180, 200). Oleh karena itu, dilakukan cleaning pada outlier.

# %%
q3=df["trestbps"].quantile(q=0.75)
q1=df["trestbps"].quantile(q=0.25)
IQR=q3-q1

## Memperoleh batas outlier
IQR_lower_limit=int(q1-1.5*IQR)
IQR_upper_limit=int(q3+1.5*IQR)
print("IQR_upper_limit for column trestbps :",IQR_upper_limit)
print("IQR_lower_limit for column trestbps :",IQR_lower_limit)

## menemukan and treating outliers-both lower dan upper end
k1=df[df["trestbps"]>IQR_upper_limit]
print("outliers on right side in trestbps is \n",k1["trestbps"],"\n")
data_cleaned=df[df["trestbps"]<IQR_upper_limit]
plt.boxplot(data_cleaned["trestbps"])
# Out:
# IQR_upper_limit for column trestbps : 170
# IQR_lower_limit for column trestbps : 90
# outliers on right side in trestbps is
#  29     180
# 47     178
# 87     174
# 137    180
# 151    192
# 175    200
# 343    172
# 396    180
# 528    178
# Name: trestbps, dtype: int64
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f569150dc60>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f569150e1a0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f569150d9c0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f569150e650>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f569150e8f0>],
#  'means': []}

# %% [markdown]
# Setelah dilakukan cleaning pada atribut trestbps tidak adanya lagi outlier.

# %% [markdown]
# **Menghapus outlier di chol**

# %%
df['chol'].unique()
# Out:
# array([212, 203, 174, 294, 248, 318, 289, 249, 286, 149, 341, 210, 298,
#        204, 308, 266, 244, 211, 185, 223, 208, 252, 209, 307, 233, 319,
#        256, 327, 169, 131, 269, 196, 231, 213, 271, 263, 229, 360, 258,
#        330, 342, 226, 228, 278, 230, 283, 241, 175, 188, 217, 193, 245,
#        232, 299, 288, 197, 315, 215, 164, 326, 207, 177, 257, 255, 187,
#        201, 220, 268, 267, 236, 303, 282, 126, 309, 186, 275, 281, 206,
#        335, 218, 254, 295, 417, 260, 240, 302, 192, 225, 325, 235, 274,
#        234, 182, 167, 172, 321, 300, 199, 564, 157, 304, 222, 184, 354,
#        160, 247, 239, 246, 409, 293, 180, 250, 221, 200, 227, 243, 311,
#        261, 242, 205, 306, 219, 353, 198, 394, 183, 237, 224, 265, 313,
#        340, 259, 270, 216, 264, 276, 322, 214, 273, 253, 176, 284, 305,
#        168, 407, 290, 277, 262, 195, 166, 178, 141])

# %% [markdown]
# Dapat terlihat pada output diatas ada bebera outlier yang mana pada angka diatas 390 - 500-an di dalam dataset, Oleh karena itu, dilakukan cleaning pada outlier.

# %%
q3=data_cleaned["chol"].quantile(q=0.75)
q1=data_cleaned["chol"].quantile(q=0.25)
IQR=q3-q1

# Memperoleh batas outlier
IQR_lower_limit=int(q1-1.5*IQR)
IQR_upper_limit=int(q3+1.5*IQR)
print("IQR_upper_limit for column chol :",IQR_upper_limit)
print("IQR_lower_limit for column chol :",IQR_lower_limit)

## menemukan and treating outliers-both lower dan upper end
k1=data_cleaned[data_cleaned["chol"]>IQR_upper_limit]
print("outliers on right side in chol is \n",k1["chol"],"\n")
data_cleaned=data_cleaned[data_cleaned["chol"]<IQR_upper_limit]
plt.boxplot(data_cleaned["chol"])
# Out:
# IQR_upper_limit for column chol : 366
# IQR_lower_limit for column chol : 118
# outliers on right side in chol is
#  123    417
# 158    564
# 179    409
# 255    394
# 450    407
# Name: chol, dtype: int64
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f569158d9f0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f569158df30>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f569158d750>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f569158e470>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f569158e710>],
#  'means': []}

# %% [markdown]
# Dapat dilihat setelah dilakukan cleaning tidak terdapat lagi outlier pada atribut chol dalam dataset.

# %% [markdown]
# **Menghapus outlier di oldpeak**

# %%
df['oldpeak'].unique()
# Out:
# array([1. , 3.1, 2.6, 0. , 1.9, 4.4, 0.8, 3.2, 1.6, 3. , 0.7, 4.2, 1.5,
#        2.2, 1.1, 0.3, 0.4, 0.6, 3.4, 2.8, 1.2, 2.9, 3.6, 1.4, 0.2, 2. ,
#        5.6, 0.9, 1.8, 6.2, 4. , 2.5, 0.5, 0.1, 2.1, 2.4, 3.8, 2.3, 1.3,
#        3.5])

# %% [markdown]
# Dapat terlihat pada output diatas ada bebera outlier yang mana pada angka diatas nilai 4 -6 di dalam dataset, Oleh karena itu, dilakukan cleaning pada outlier.

# %%
q3=data_cleaned["oldpeak"].quantile(q=0.75)
q1=data_cleaned["oldpeak"].quantile(q=0.25)
IQR=q3-q1
## Memperoleh batas outlier
IQR_lower_limit=int(q1-1.5*IQR)
IQR_upper_limit=int(q3+1.5*IQR)
print("IQR_upper_limit for column oldpeak :",IQR_upper_limit)
print("IQR_lower_limit for column oldpeak :",IQR_lower_limit)

## menemukan and treating outliers-both lower dan upper end
k1=data_cleaned[data_cleaned["oldpeak"]>IQR_upper_limit]
print("outliers on right side in oldpeak is \n",k1["oldpeak"],"\n")
data_cleaned=data_cleaned[data_cleaned["oldpeak"]<IQR_upper_limit]
plt.boxplot(data_cleaned["oldpeak"])
# Out:
# IQR_upper_limit for column oldpeak : 4
# IQR_lower_limit for column oldpeak : -2
# outliers on right side in oldpeak is
#  6     4.4
# 13    4.2
# 54    5.6
# 69    6.2
# Name: oldpeak, dtype: float64
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f56913df400>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f56913df940>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f56913de0b0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f56913dfe80>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f5691410160>],
#  'means': []}

# %% [markdown]
# Dapat terlihat pada output setelah dilakukan cleaning tidak terdapat lagi outlier dalam dataset di atribut oldpeak.

# %% [markdown]
# **Menghapus outlier di thalach**

# %%
df['thalach'].unique()
# Out:
# array([168, 155, 125, 161, 106, 122, 140, 145, 144, 116, 136, 192, 156,
#        142, 109, 162, 165, 148, 172, 173, 146, 179, 152, 117, 115, 112,
#        163, 147, 182, 105, 150, 151, 169, 166, 178, 132, 160, 123, 139,
#        111, 180, 164, 202, 157, 159, 170, 138, 175, 158, 126, 143, 141,
#        167,  95, 190, 118, 103, 181, 108, 177, 134, 120, 171, 149, 154,
#        153,  88, 174, 114, 195, 133,  96, 124, 131, 185, 194, 128, 127,
#        186, 184, 188, 130,  71, 137,  99, 121, 187,  97,  90, 129, 113])

# %% [markdown]
# Dapat terlihat pada output diatas ada bebera outlier yang mana pada angka diatas adalah 71. Oleh karena itu, dilakukan cleaning pada outlier.

# %%
q3=data_cleaned["thalach"].quantile(q=0.75)
q1=data_cleaned["thalach"].quantile(q=0.25)
IQR=q3-q1
## Memperoleh batas outlier
IQR_lower_limit=int(q1-1.5*IQR)
print("IQR_lower_limit for column oldpeak :",IQR_lower_limit)

## menemukan and treating outliers-both lower dan upper end
k1=data_cleaned[data_cleaned["thalach"]<IQR_lower_limit]
print("outliers on left side in thalach is \n",k1["thalach"],"\n")
data_cleaned=data_cleaned[data_cleaned["thalach"]>IQR_lower_limit]
plt.boxplot(data_cleaned["thalach"])
# Out:
# IQR_lower_limit for column oldpeak : 78
# outliers on left side in thalach is
#  267    71
# Name: thalach, dtype: int64
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f569145b370>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f569145b8b0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f569145b0d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f569145bdf0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f56914880d0>],
#  'means': []}

# %% [markdown]
# Dapat dilihat setelah dilakukan cleaning pada atribut thalach tidak adanya lagi outlier

# %% [markdown]
# **Kembali memeriksa outlier**

# %%
plt.figure(figsize=(20,20), facecolor='white')

plotnumber=1
for column in data_cleaned.columns:
    if plotnumber<15 :
        plt.subplot(4,4,plotnumber)
        plt.boxplot(data_cleaned[column])
        plt.ylabel(column,fontsize=20)
    plotnumber+=1
plt.show()

# %% [markdown]
# <a id="5"></a>
#
#
# <font color="PURPLE" size=+1.5><b> Memeriksa data untuk imbalance</b></font>

# %%
sns.countplot(data=df,x='target')
# Out:
# <Axes: xlabel='target', ylabel='count'>

# %%
df['target'].value_counts()
# Out:
# 1    164
# 0    138
# Name: target, dtype: int64

# %% [markdown]
# Dapat dilihat pada output diatas data cukup seimbang (balanced), karena tidak terdapat perbedaan yang signifikan.

# %% [markdown]
# ##**Periksa statistik deskriptif dari kumpulan data (rata-rata, distribusi, dll)**

# %%
# Melihat statistik deskriptif dari data
df.describe()
# Out:
#              age    trestbps        chol     thalach     oldpeak      target
# count  302.00000  302.000000  302.000000  302.000000  302.000000  302.000000
# mean    54.42053  131.602649  246.500000  149.569536    1.043046    0.543046
# std      9.04797   17.563394   51.753489   22.903527    1.161452    0.498970
# min     29.00000   94.000000  126.000000   71.000000    0.000000    0.000000
# 25%     48.00000  120.000000  211.000000  133.250000    0.000000    0.000000
# 50%     55.50000  130.000000  240.500000  152.500000    0.800000    1.000000
# 75%     61.00000  140.000000  274.750000  166.000000    1.600000    1.000000
# max     77.00000  200.000000  564.000000  202.000000    6.200000    1.000000

# %% [markdown]
# Dari kumpulan data yang diberikan, dapat dilihat bahwa terdapat 302 entri dan 6 kolom. Berikut adalah statistik deskriptif dari setiap variabel:
# * age: umur pasien, dengan rata-rata (mean) 54.42 tahun dan rentang antara 29 hingga 77 tahun.
# * trestbps: tekanan darah saat istirahat (resting blood pressure) dalam mmHg, dengan rata-rata 131.6 dan rentang antara 94 hingga 200.
# * chol: serum kolesterol dalam mg/dl, dengan rata-rata 246.5 dan rentang antara 126 hingga 564.
# * thalach: detak jantung maksimal yang dicapai selama tes olahraga, dengan rata-rata 149.57 dan rentang antara 71 hingga 202.
# * oldpeak: depresi ST (ST depression) relatif terhadap istirahat yang diinduksi oleh olahraga, dengan rata-rata 1.043 dan rentang antara 0 hingga 6.2.
# * target: variabel target yang menunjukkan keberadaan atau tidaknya penyakit jantung, dengan nilai 0 menunjukkan tidak adanya penyakit dan nilai 1 menunjukkan adanya penyakit.

# %% [markdown]
# <a id="5"></a>
#
#
# <font color="PURPLE" size=+1.5><b>Memvisualisasikan distribusi variabel numerical</b></font>

# %%
plt.figure(figsize=(16,8))
for index,column in enumerate(numerical_col):
    plt.subplot(2,3,index+1)
    sns.histplot(data=numerical_col,x=column,kde=True)
    plt.xticks(rotation = 90)
plt.tight_layout(pad = 1.0)
plt.show()

# %% [markdown]
# <a id="5"></a>
#
#
# <font color="PURPLE" size=+1.5><b>Memvisualisasikan distribusi variabel kategorical</b></font>

# %%
plt.figure(figsize=(12,12))
for index,column in enumerate(categorical_col):
    plt.subplot(4,2,index+1)
    sns.countplot(data=categorical_col,x=column)
    plt.xlabel(column.upper(),fontsize=14)
    plt.ylabel("count", fontsize=14)

plt.tight_layout(pad = 1.0)
plt.show()

# %% [markdown]
# ##**Memeriksa korelasi antar fitur**

# %%
plt.figure(figsize=(20,20))
cor=df.corr()
sns.heatmap(cor,annot=True)
# Out:
# <Axes: >

# %%
cor_matrix = df.corr()
cor_matrix
# Out:
#                age  trestbps      chol   thalach   oldpeak    target
# age       1.000000  0.283121  0.207216 -0.395235  0.206040 -0.221476
# trestbps  0.283121  1.000000  0.125256 -0.048023  0.194600 -0.146269
# chol      0.207216  0.125256  1.000000 -0.005308  0.050086 -0.081437
# thalach  -0.395235 -0.048023 -0.005308  1.000000 -0.342201  0.419955
# oldpeak   0.206040  0.194600  0.050086 -0.342201  1.000000 -0.429146
# target   -0.221476 -0.146269 -0.081437  0.419955 -0.429146  1.000000

# %%
fig = plt.figure(figsize=(15,9))
for index in range(len(numerical_col.columns)):
    plt.subplot(2,3,index + 1)
    sns.scatterplot(x = numerical_col.iloc[:,index],y=df.target,data = numerical_col)
    plt.xlabel( numerical_col.columns[index], fontsize=14)
    plt.ylabel("Target", fontsize=14)

fig.tight_layout(pad = 1.0)

# %% [markdown]
# *   Korelasi antara umur (age) dan target menunjukkan adanya hubungan yang lemah antara umur dengan keberadaan penyakit jantung (target).
# *   Korelasi antara variabel 'trestbps' (tekanan darah saat istirahat) dan 'target' (penyakit jantung) menunjukkan adanya korelasi yang lemah antara trestbps dan penyakit jantung pada dataset yang digunakan.
# *    Korelasi antara chol dan target menunjukkan adanya hubungan linier negatif yang lemah antara kedua variabel tersebut.
# *    Nilai korelasi antara thalach (maximum heart rate achieved) dan target menunjukkan adanya hubungan positif yang sedang antara kedua variabel tersebut. Artinya, semakin tinggi thalach, semakin tinggi pula kemungkinan seseorang mengalami penyakit jantung.
# *    Korelasi antara oldpeak dan target menunjukkan adanya korelasi negatif yang sedang antara kedua variabel tersebut. Ini berarti semakin tinggi nilai oldpeak, semakin rendah kemungkinan seseorang memiliki penyakit jantung (ditunjukkan oleh nilai target yang sama dengan 0), dan sebaliknya semakin rendah nilai oldpeak, semakin tinggi kemungkinan seseorang memiliki penyakit jantung (ditunjukkan oleh nilai target yang sama dengan 1).

# %% [markdown]
# ##**Exploratory Data Analysis melalui Dataprep, Autovis, Dtale, dll**

# %% [markdown]
# <a id="5"></a>
#
#
# <font color="PURPLE" size=+1.5><b>Dataprep</b></font>

# %%
create_report(df).show()

# %% [markdown]
# <a id="9"></a>
#
#
# <font color="GRAY" size=+3><b> ASSIGNMENT 3 </b></font>
#
# <a id="4"></a>
#
# ---

# %% [markdown]
# **Hypothesis :**
#
# Berdasarkan proses EDA yang dilakukan didapatkan hipotesis :
#
# - Orang - orang yang memiliki jenis nyeri dada tipe typical angina, atypical angina, non-anginal pain, dan asymptomatic berpeluang besar untuk mendapatkan diagnosa penyakit jantung.
# - Orang - orang yang mempunyai jumlah detak jantung permenit yang banyak akan  berpeluang di diagnosa penyakit jantung.
# - Semua jenis kelamin dan usia berpeluang menderita penyakit jantung.
# - Tingkat kerusakan jantung mempengaruhi hasil diagnosa penyakit jantung.
# - Kadar gula darah yang tinggi, tidak mempengaruhi hasil diagnosa penyakit jantung.

# %% [markdown]
# **Memilih model :**
#
# Pada pemilihan model yang akan digunakan kali ini adalah decission tree dan juga random fores. Dimana seperti diketahui bahwa decission tree merupakan algoritma machine learning yang mendasar dan cukup menghasilkan akurasi yang cukup bagus. Sedangkan, random forest digunakan juga karena merupakan pengembangan dari algoritma machine learning decission tree dan juga menghasilkan akurasi yang cenderung lebih bagus bila dibandingkan dengan decission tree.

# %% [markdown]
# **Memilih model evaluation :**
#
# Model evaluasi yang akan digunakan adalah akurasi, presisi, dan recall
#
# - Akurasi digunakan untuk melihat rasio prediksi Benar (positif dan negatif) dengan keseluruhan data.
# - Presisi digunakan untuk melihat rasio prediksi benar positif dibandingkan dengan keseluruhan hasil yang diprediksi positf.
# - Recall digunakan untuk melihat rasio prediksi benar positif dibandingkan dengan keseluruhan data yang benar positif.
# - F1 Score merupakan perbandingan rata-rata presisi dan recall yang dibobotkan

# %% [markdown]
# ##**Membuat Hypotesis**

# %% [markdown]
# **Correlation Test**
#
# Uji korelasi yang akan dilakukan adalah uji korelasi pearson.
# - Menguji korelasi antara kadar kolestrol pasien (chol) dan kesehatan jantung pasien (target)

# %%
from scipy import stats
stat, p = stats.pearsonr(df['chol'], df['target'])
stat, p
# Out:
# (-0.08143720051844147, 0.15803697464249764)

# %%
if p > 0.05:
    print('H0 diterima, artinya kadar kolestrol pasien tidak berkorelasi dengan kesehatan jantung pasien')
else:
    print('H0 ditolak dan H1 diterima, artinya kadar kolestrol pasien berkorelasi dengan kesehatan jantung pasien')
# Out:
# H0 diterima, artinya kadar kolestrol pasien tidak berkorelasi dengan kesehatan jantung pasien

# %% [markdown]
# - Menguji korelasi antara umur pasien (age) dan kesehatan jantung pasien (target)

# %%
from scipy import stats
stat, p = stats.pearsonr(df['age'], df['target'])
stat, p
# Out:
# (-0.2214758277665622, 0.00010394837285416736)

# %%
if p > 0.05:
    print('H0 diterima, artinya umur pasien tidak berkorelasi dengan kesehatan jantung pasien')
else:
    print('H0 ditolak dan H1 diterima, artinya umur pasien berkorelasi dengan kesehatan jantung pasien')
# Out:
# H0 ditolak dan H1 diterima, artinya umur pasien berkorelasi dengan kesehatan jantung pasien

# %% [markdown]
# **Normality Test**
#
# Dalam statistik , uji normalitas digunakan untuk menentukan apakah kumpulan data dimodelkan dengan baik oleh distribusi normal dan untuk menghitung seberapa mungkin variabel acak yang mendasari dataset akan didistribusikan secara normal. Uji normalitas yang akan dilakukan kali ini adalah uji Jarque Bera. Dimana:
# - H0 : Data berdistribusi normal
# - H1 : Data tidak berdistribusi normal

# %%
from scipy import stats
stat, p = stats.jarque_bera(df['chol'])
stat, p
# Out:
# (314.5494647911561, 4.971089448474556e-69)

# %% [markdown]
# Berdasarkan uji jarque bera, diperoleh p-value = 4.971089 > α = 0.05. Dengan menggunakan tingkat kepercayaan 95%, data yang ada mendukung bahwa data berdistribusi normal.

# %%
from scipy import stats
stat, p = stats.jarque_bera(df['age'])
stat, p
# Out:
# (5.719254279301177, 0.057290117496815236)

# %%
if p > 0.05:
    print('H0 diterima, artinya umur pasien berdistribusi normal')
else:
    print('H0 ditolak dan H1 diterima, artinya umur pasien tidak berdistribusi normal')
# Out:
# H0 diterima, artinya umur pasien berdistribusi normal

# %% [markdown]
# Berdasarkan uji jarque bera, diperoleh p-value = 0.05729 > α = 0.05. Dengan menggunakan tingkat kepercayaan 95%, data yang ada mendukung bahwa data berdistribusi normal.

# %% [markdown]
# ##**Memisahkan Variabel Dependen dan Independen**

# %% [markdown]
# Variabel dependen yang digunakan adalah data pada kolom 'target', kolom lainnya merupakan variabel independen. Pisahkan variabel independen sebagai X dan dependen sebagai y!

# %%
X = df.drop('target', axis=1)
y = df['target']

# %%
#Melihat kolom yang termasuk variable indepnden
X
# Out:
#      age sex cp  trestbps  chol fbs restecg  thalach exang  oldpeak slope ca  \
# 0     52   1  0       125   212   0       1      168     0      1.0     2  2
# 1     53   1  0       140   203   1       0      155     1      3.1     0  0
# 2     70   1  0       145   174   0       1      125     1      2.6     0  0
# 3     61   1  0       148   203   0       1      161     0      0.0     2  1
# 4     62   0  0       138   294   1       1      106     0      1.9     1  3
# ..   ...  .. ..       ...   ...  ..     ...      ...   ...      ...   ... ..
# 723   68   0  2       120   211   0       0      115     0      1.5     1  0
# 733   44   0  2       108   141   0       1      175     0      0.6     1  0
# 739   52   1  0       128   255   0       1      161     1      0.0     2  1
# 843   59   1  3       160   273   0       0      125     0      0.0     2  0
# 878   54   1  0       120   188   0       1      113     0      1.4     1  1
#
#     thal
# 0      3
# 1      3
# 2      3
# ...

# %%
# Melihat variabel dependen
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 723    1
# 733    1
# 739    0
# 843    0
# 878    0
# Name: target, Length: 302, dtype: int64

# %% [markdown]
# ## **Scalling Dataset**

# %%
# Import library StandartScaler yang akan digunakan
from sklearn.preprocessing import StandardScaler

# Mendefinisikan standard scaler
scaler = StandardScaler()
scaler.fit_transform(X)
# Out:
# array([[-0.26796589,  0.68265615, -0.93520799, ...,  0.97951442,
#          1.27497996,  1.11996657],
#        [-0.15726042,  0.68265615, -0.93520799, ..., -2.27118179,
#         -0.71491124,  1.11996657],
#        [ 1.72473259,  0.68265615, -0.93520799, ..., -2.27118179,
#         -0.71491124,  1.11996657],
#        ...,
#        [-0.26796589,  0.68265615, -0.93520799, ...,  0.97951442,
#          0.28003436,  1.11996657],
#        [ 0.50697241,  0.68265615,  1.97647049, ...,  0.97951442,
#         -0.71491124, -0.51399432],
#        [-0.04655495,  0.68265615, -0.93520799, ..., -0.64583368,
#          0.28003436,  1.11996657]])

# %%
from sklearn import preprocessing

X = preprocessing.scale(X)

# %% [markdown]
# Scaling adalah suatu cara untuk membuat numerical data pada dataset memiliki rentang nilai (scale) yang sama. Tidak ada lagi satu variabel data yang mendominasi variabel data lainnya. Scaling ini juga termasuk kedalam proses preprocessing oleh sebab itu code-nya seperti contoh diatas.

# %% [markdown]
# ##**Spltting Dataset**
#
# Pisahkan dataset menjadi training dan testing dataset dengan perbandingan 80:20!

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2, random_state=100)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (241, 13)
# (61, 13)
# (241,)
# (61,)

# %% [markdown]
# Proses splitting data merupakan pembagian data menjadi data untuk training dan data untuk testing dimana disini saya membagi menjadi 80% data training dan 20% data testing, karena semakin banyak data yang dilatih mesin akan semakin banyak belajar sehingga bisa optimal dalam membangun model nantinya, dimana dengan random state sebanyak 100.

# %% [markdown]
# ##**Model Fitting**##

# %% [markdown]
# Build model klasifikasi machine learning menggunakan model Decision Tree dan Random Forest, tiap model akan digunakan cross validation dan bootstrapping.
#
# Random Forest dan Decision Tree cocok untuk melakukan klasifikasi pada data heart disease karena model ini dapat memetakan pola dan hubungan antara variabel independen dengan variabel target, serta dapat memecah data menjadi subset yang lebih kecil untuk meningkatkan akurasi model.

# %%
# Melakukan import library yang diperlukan
from sklearn import tree
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, ConfusionMatrixDisplay, precision_score, recall_score, f1_score
from sklearn.model_selection import cross_val_score

# %% [markdown]
# ##**Model Decision Tree**##

# %%
from sklearn.tree import DecisionTreeClassifier # model fitting and prediction
from sklearn.metrics import classification_report, confusion_matrix # checking performance of model

model1 = DecisionTreeClassifier().fit(X_train, y_train)
pred = model1.predict(X_test)

print('CONFUSION MATRIX')
print(confusion_matrix(y_test, pred))
# Out:
# CONFUSION MATRIX
# [[18  2]
#  [ 5 36]]

# %%
print('CLASSIFICATION REPORT')
print(classification_report(y_test, pred))
# Out:
# CLASSIFICATION REPORT
#               precision    recall  f1-score   support
#
#            0       0.78      0.90      0.84        20
#            1       0.95      0.88      0.91        41
#
#     accuracy                           0.89        61
#    macro avg       0.86      0.89      0.87        61
# weighted avg       0.89      0.89      0.89        61

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_test, pred)
print(f'Accuracy yang didapatkan dari Decession Tree: {accuracy:.2f}')
# Out:
# Accuracy yang didapatkan dari Decession Tree: 0.89

# %% [markdown]
# Jadi dapat terlihat pada report akurasi yang dihasilkan dari model Decission Tree cukup baik dimana menyentuh angka 89%. Serta perbedaan recall, precision, dan f1-score nya tidak terpaut jauh artinya model ini sudah cukup baik.

# %% [markdown]
# <a id="4"></a>
#
# <font color="BROWN" size=+1.5><b> Cross Validation</b></font>

# %%
# Evaluasi model dengan K-Fold Validation
scores = cross_val_score(model1, X_train, y_train, cv=5)
# Melihat performa dalam akurasi
print("Akurasi Decission Tree di data train dengan menggunakan cross-validation: %.2f dengan standard deviation %.2f" % (scores.mean(), scores.std()))
# Out:
# Akurasi Decission Tree di data train dengan menggunakan cross-validation: 0.76 dengan standard deviation 0.08

# %%
# Evaluasi model dengan K-Fold Validation
scores = cross_val_score(model1, X_test, y_test, cv=5)
# Melihat performa dalam akurasi
print("Akurasi Decission Tree di semua data dengan menggunakan cross-validation: %.2f dengan standard deviation %.2f" % (scores.mean(), scores.std()))
# Out:
# Akurasi Decission Tree di semua data dengan menggunakan cross-validation: 0.74 dengan standard deviation 0.08

# %%
#Features imprtances dengan decision tree
X = pd.DataFrame(X)
coef_dtc = pd.Series(model1.feature_importances_, index = X.columns)
plt.figure(figsize=(15,5))
imp_coef_dtc = coef_dtc.sort_values()
imp_coef_dtc.plot(kind = "barh")
plt.title("Feature importance using Decision Tree")
# Out:
# Text(0.5, 1.0, 'Feature importance using Decision Tree')

# %% [markdown]
# <a id="4"></a>
#
# <font color="BROWN" size=+1.5><b> Bootstrapping</b></font>

# %%
from sklearn.utils import resample

# Use bootstrapping to estimate the accuracy of the model
n_bootstraps = 100
accuracies = []
for i in range(n_bootstraps):
    # Sample the data with replacement
    X_boost, y_boost = resample(X_train, y_train)
    # Train the model on the bootstrap sample
    model1.fit(X_boost, y_boost)
    # Evaluate the model on the entire dataset
    y_pred = model1.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    accuracies.append(accuracy)

# Calculate the mean and confidence interval of the accuracies
mean_accuracy = np.mean(accuracies)
std_accuracy = np.std(accuracies)
lower_ci = mean_accuracy - 1.96 * std_accuracy
upper_ci = mean_accuracy + 1.96 * std_accuracy

# Print the results
print("Mean akurasi Decission Tree dengan bootstrapping: %.2f" % mean_accuracy)
print("95%% confidence interval: [%.2f, %.2f]" % (lower_ci, upper_ci))
# Out:
# Mean akurasi Decission Tree dengan bootstrapping: 0.75
# 95% confidence interval: [0.67, 0.84]

# %% [markdown]
# **Insight :**
#
# Penggunaan decission tree baseline menghasilkan akurasi 85% dan presisi 86% dengan cross validation adalah 79% dan penggunaan bootstrapping juga menghasilkan akurasi 76% dengan fitur yang paling mempengaruhi adalah CP (jenis nyeri dada) dengan score 0.27759 sedangkan fitur lainnnya kurang dari 0,2.

# %% [markdown]
# ##**Model Random Forest**##

# %%
from sklearn.ensemble import RandomForestClassifier # model fitting and prediction
from sklearn.metrics import classification_report, confusion_matrix # checking performance of model

model2 = RandomForestClassifier().fit(X_train, y_train)
pred = model1.predict(X_test)

print('CONFUSION MATRIX')
print(confusion_matrix(y_test, pred))
# Out:
# CONFUSION MATRIX
# [[15  5]
#  [11 30]]

# %%
print('CLASSIFICATION REPORT')
print(classification_report(y_test, pred))
# Out:
# CLASSIFICATION REPORT
#               precision    recall  f1-score   support
#
#            0       0.58      0.75      0.65        20
#            1       0.86      0.73      0.79        41
#
#     accuracy                           0.74        61
#    macro avg       0.72      0.74      0.72        61
# weighted avg       0.77      0.74      0.74        61

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_test, pred)
print(f'Accuracy yang didapatkan dari Random Forest: {accuracy:.2f}')
# Out:
# Accuracy yang didapatkan dari Random Forest: 0.74

# %% [markdown]
# Model random forest ini hanya menghasilkan sebesar 74% yang mana kurang baik karena kurang dari 80%, namun precission, recall, dan f1-score tidak terlalu terpaut jauh.

# %% [markdown]
# <a id="4"></a>
#
# <font color="BROWN" size=+1.5><b> Cross Validation</b></font>

# %%
from sklearn.model_selection import cross_val_score

# %%
# Evaluasi model dengan K-Fold Validation
scores = cross_val_score(model2, X_train, y_train, cv=5)
# Melihat performa dalam akurasi
print("Akurasi Random Forest di data train dengan menggunakan cross-validation: %.2f dengan standard deviation %.2f" % (scores.mean(), scores.std()))
# Out:
# Akurasi Random Forest di data train dengan menggunakan cross-validation: 0.82 dengan standard deviation 0.04

# %%
# Evaluasi model dengan K-Fold Validation
scores = cross_val_score(model2, X_test, y_test, cv=5)
# Melihat performa dalam akurasi
print("Akurasi Random Forest di semua data dengan menggunakan cross-validation: %.2f dengan standard deviation %.2f" % (scores.mean(), scores.std()))
# Out:
# Akurasi Random Forest di semua data dengan menggunakan cross-validation: 0.87 dengan standard deviation 0.07

# %%
#Features imprtances dengan decision tree
X = pd.DataFrame(X)
coef_dtc = pd.Series(model2.feature_importances_, index = X.columns)
plt.figure(figsize=(15,5))
imp_coef_dtc = coef_dtc.sort_values()
imp_coef_dtc.plot(kind = "barh")
plt.title("Feature importance using Random Forest")
# Out:
# Text(0.5, 1.0, 'Feature importance using Random Forest')

# %% [markdown]
# <a id="4"></a>
#
# <font color="BROWN" size=+1.5><b> Bootstrapping</b></font>

# %%
from sklearn.utils import resample

# Use bootstrapping to estimate the accuracy of the model
n_bootstraps = 100
accuracies = []
for i in range(n_bootstraps):
    # Sample the data with replacement
    X_boost, y_boost = resample(X_train, y_train)
    # Train the model on the bootstrap sample
    model2.fit(X_boost, y_boost)
    # Evaluate the model on the entire dataset
    y_pred = model2.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    accuracies.append(accuracy)

# Calculate the mean and confidence interval of the accuracies
mean_accuracy = np.mean(accuracies)
std_accuracy = np.std(accuracies)
lower_ci = mean_accuracy - 1.96 * std_accuracy
upper_ci = mean_accuracy + 1.96 * std_accuracy

# Print the results
print("Mean akurasi Random Forest dengan bootstrapping: %.2f" % mean_accuracy)
print("95%% confidence interval: [%.2f, %.2f]" % (lower_ci, upper_ci))
# Out:
# Mean akurasi Random Forest dengan bootstrapping: 0.83
# 95% confidence interval: [0.77, 0.89]

# %% [markdown]
# **Insight :**
#
# Penggunaan decision tree ternya menghasilkan akurasi yang lebih baik bila dibandingkan dengan random forest dimana pada random forest dihasilkan yaitu akurasi baseline 74% dan presisi 72% dengan menggunakan cross validation adalah 82% dan penggunaan bootsrapping menghasilkan akurasi 83% dengan fitur yang paling mempengaruhi yang cukup merata yang mana terdapat 3 fitur yang paling mempengaruhi akurasi yaitu cp(Jenis nyeri dada), ca, thalach (detak jantung maksimum yang dicapai) dengan score yang sama rata antara keduanya.

# %% [markdown]
# **Conclusion :**
#
# Dapat disimpulkan bahwa penggunaan pemodelan Decision tree dengan kombinasi cross validation dan bootsrapping menghasilkan akurasi dan presisi yang lebih tinggi bila dibandingkan dengan random forest yang menghasilkan akurasi dan presisi yang kurang dari 80% dan terdapat 3 fitur yang paling mempengaruhi akurasi dari penggunaan model decission tree dan random forest yaitu ca, cp (jenis nyeri dada), dan thalach (detak jantung maksimum permenit).
#
# Berdasarkan proses yang dilakukan didapatkan hasil hipotesis :
#
# - Orang yang memiliki jenis nyeri dada tipe typical angina, atypical angina, non-anginal pain, dan asymptomatic berpeluang besar untuk didiagnosa penyakit jantung (hipotesis diterima).
# - Orang yang mempunyai jumlah detak jantung permenit yang banyak berpeluang didiagnosa penyakit jantung (hipotesis diterima).
# - Pada hipotesis ini, ada kecenderungan usia dan jenis kelamin tertentu yang kemungkinan besar didiagnosa penyakit jantung namun tetap bisa dikatakan semua usia diatas 29 tahun berpeluang didiagnosa penyakit jantung (hipotesis diterima).
# - Tingkat kerusakan jantung mempengaruhi hasil diagnosa penyakit jantung (hipotesis diterima).
# - Kadar gula darah yang tinggi, tidak mempengaruhi hasil diagnosa penyakit jantung (hipotesis diterima).
